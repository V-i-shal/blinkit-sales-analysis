# %% [markdown]
# **BLINKIT ANALYSIS PROJECT**

# %% [markdown]
# **LIBRARIES**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **RAW DATA SET**

# %%
df=pd.read_csv("C:/Users/visha/Downloads/blinkit_data.csv")

# %%
df.head(10)
# Out:
#   Item Fat Content Item Identifier              Item Type  \
# 0          Regular           FDX32  Fruits and Vegetables
# 1          Low Fat           NCB42     Health and Hygiene
# 2          Regular           FDR28           Frozen Foods
# 3          Regular           FDL50                 Canned
# 4          Low Fat           DRI25            Soft Drinks
# 5          low fat           FDS52           Frozen Foods
# 6          Low Fat           NCU05     Health and Hygiene
# 7          Low Fat           NCD30              Household
# 8          Low Fat           FDW20  Fruits and Vegetables
# 9          Low Fat           FDX25                 Canned
#
#    Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 0                       2012            OUT049               Tier 1
# 1                       2022            OUT018               Tier 3
# 2                       2010            OUT046               Tier 1
# ...

# %%
df.describe()
# Out:
#        Outlet Establishment Year  Item Visibility  Item Weight        Sales  \
# count                8523.000000      8523.000000  7060.000000  8523.000000
# mean                 2010.831867         0.066132    12.857645   140.992782
# std                     8.371760         0.051598     4.643456    62.275067
# min                  1998.000000         0.000000     4.555000    31.290000
# 25%                  2000.000000         0.026989     8.773750    93.826500
# 50%                  2012.000000         0.053931    12.600000   143.012800
# 75%                  2017.000000         0.094585    16.850000   185.643700
# max                  2022.000000         0.328391    21.350000   266.888400
#
#             Rating
# count  8523.000000
# mean      3.965857
# std       0.605651
# min       1.000000
# 25%       4.000000
# 50%       4.000000
# 75%       4.200000
# max       5.000000

# %%
df.tail(10)
# Out:
#      Item Fat Content Item Identifier              Item Type  \
# 8513          Regular           DRY23            Soft Drinks
# 8514          low fat           FDA11           Baking Goods
# 8515          low fat           FDK38                 Canned
# 8516          low fat           FDO38                 Canned
# 8517          low fat           FDG32  Fruits and Vegetables
# 8518          low fat           NCT53     Health and Hygiene
# 8519          low fat           FDN09            Snack Foods
# 8520          low fat           DRE13            Soft Drinks
# 8521              reg           FDT50                  Dairy
# 8522              reg           FDM58            Snack Foods
#
#       Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 8513                       1998            OUT027               Tier 3
# 8514                       1998            OUT027               Tier 3
# 8515                       1998            OUT027               Tier 3
# ...

# %%
print("Size of data:",df.shape)
# Out:
# Size of data: (8523, 12)

# %%
df.columns
# Out:
# Index(['Item Fat Content', 'Item Identifier', 'Item Type',
#        'Outlet Establishment Year', 'Outlet Identifier',
#        'Outlet Location Type', 'Outlet Size', 'Outlet Type', 'Item Visibility',
#        'Item Weight', 'Sales', 'Rating'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Item Fat Content              object
# Item Identifier               object
# Item Type                     object
# Outlet Establishment Year      int64
# Outlet Identifier             object
# Outlet Location Type          object
# Outlet Size                   object
# Outlet Type                   object
# Item Visibility              float64
# Item Weight                  float64
# Sales                        float64
# Rating                       float64
# dtype: object

# %% [markdown]
# **DATA CLEANING**

# %%
print (df['Item Fat Content'].unique())
# Out:
# ['Regular' 'Low Fat' 'low fat' 'LF' 'reg']

# %%
print (df['Item Type'].unique())
# Out:
# ['Fruits and Vegetables' 'Health and Hygiene' 'Frozen Foods' 'Canned'
#  'Soft Drinks' 'Household' 'Snack Foods' 'Meat' 'Breads' 'Hard Drinks'
#  'Others' 'Dairy' 'Breakfast' 'Baking Goods' 'Seafood' 'Starchy Foods']

# %%
df['Item Fat Content' ]=df['Item Fat Content' ].replace({'LF':'Low Fat','LF':'Low Fat','reg':'Regular','low fat':'Low Fat'})

# %%
df.to_csv("cleaned_blinkit_data.csv", index=False)

# %% [markdown]
# **REQUIREMENTS**

# %%
#Total Sales
total_sales=df['Sales'].sum()

Average_sales=df['Sales'].mean()

No_of_items_sold=df['Sales'].count()

Average_ratings=df['Rating'].mean()

print (f"Total sales: ${total_sales:,}")
print (f"Average sales: ${Average_sales:,.0f}")
print (f"No of items : ${No_of_items_sold:,}")
print (f"Average Ratings: {Average_ratings:,.0f}")
# Out:
# Total sales: $1,201,681.4808
# Average sales: $141
# No of items : $8,523
# Average Ratings: 4

# %% [markdown]
# **Total Sales by Fat Content**

# %%
sales_by_fat=df.groupby('Item Fat Content')['Sales'].sum()

plt.pie(sales_by_fat,labels=sales_by_fat.index,autopct="%.0f%%",startangle=90)
plt.axis("equal")
plt.title("Total sales by fat")
plt.show()

# %% [markdown]
# **Total Sales by Item Type**

# %%
sales_by_itemtype=df.groupby('Item Type')['Sales'].sum().sort_values(ascending=False)
plt.figure(figsize=(10,6))
bar=plt.bar(sales_by_itemtype.index,sales_by_itemtype.values)
plt.xticks(rotation=-90)
plt.xlabel("Item type")
plt.ylabel("Sales")
plt.title("TOTAL SALES OF ITEM")

for bars in bar:
    height=bars.get_height()
    plt.text(bars.get_x()+bars.get_width()/2,height+1000,
             f'{height:,.0f}',ha="center",va="bottom",fontsize=8)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Fat Content by Outlet for Total Sales**

# %%
grouped=df.groupby(['Outlet Location Type','Item Fat Content'])['Sales'].sum().unstack()
grouped=grouped[['Regular','Low Fat']]

ax=grouped.plot(kind='bar',figsize=(8,5),title=("Fat Content by Outlet for Total Sales"))
plt.xlabel("outlet location")
plt.ylabel("Sales")
plt.legend(title="Item Fat Content")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Total Sales by Outlet Establishment**

# %%
sale_by_year=df.groupby('Outlet Establishment Year')['Sales'].sum().sort_index()

plt.figure(figsize=(9,5))
plt.plot(sale_by_year.index,sale_by_year.values,marker='o',linestyle='-')
plt.title("Total Sales by Outlet Establishment")
plt.xlabel("Outlet Establishment Year")
plt.ylabel("Sales")

for x, y in zip (sale_by_year.index,sale_by_year.values):
    plt.text(x,y,f'{y:,.0f}',ha="center",va="bottom",fontsize=8)
plt.tight_layout()
plt.show()

# %%
sales_by_outlet=df.groupby('Outlet Size')['Sales'].sum()

plt.pie(sales_by_outlet,labels=sales_by_outlet.index,autopct="%.0f%%",startangle=90)
plt.axis("equal")
plt.title("Total sales by Outlet")
plt.show()
